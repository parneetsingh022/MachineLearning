# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("data/home_data.csv")
TRAIN_SIZE = int(0.8*len(df))

train_df = df[0:TRAIN_SIZE]
test_df = df[TRAIN_SIZE:]
df.tail()
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21608      1131     3.0           0     0  ...      8        1530
# 21609      5813     2.0           0     0  ...      8        2310
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
comp = ['lat', 'long','bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'yr_built','condition', 'waterfront','view', 'grade','sqft_above', 'sqft_basement']

reg = linear_model.LinearRegression()

reg.fit(
    train_df[comp],
    train_df.price
)

reg.score(test_df[comp], test_df.price)
# Out:
# 0.6873095197504057

# %%
reg.predict([[47.5941,-122.299,2,0.75,1020,1076,2.0,2008,3,0,0,7,1020,0]])
# Out:
# array([144345.87358562])
